# %% [markdown]
# # Probability exercises

# %%
from scipy.special import binom
import itertools

A = {1,2,3,4}
k= 2

# %%
n = len(A)
choose_k = list(itertools.combinations(A,k))
choose_k
# Out:
# [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]

# %%
print("%i-combinations of %s: "%(k,A))
for i in choose_k:
    print(i)

print; print("Number of combinations  = %i!/(%i!(%i-%i))! = "%(n,k,n,k),len(choose_k))
# Out:
# 2-combinations of {1, 2, 3, 4}:
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# Number of combinations  = 4!/(2!(4-2))! =  6

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mi_funcion_pi(N=10000):    
    
    # generar puntos aleatorios
    x, y = np.random.uniform(0, 1, size=(2, N))

    # exito
    interior = (x**2 + y**2) <= 1 # menores a 1 
    #no exito
    exterior = 1-interior

    # grafica
    plt.plot(x[interior], y[interior], 'b.')
    plt.plot(x[exterior], y[exterior], 'r.')

    #calculo
    p = interior.sum()/ N

    #sumar 4 veces el area
    pi = p*4
    error = abs((pi - np.pi) / pi) * 100

    #grafica
    plt.plot(0, 0, label='N={:d}\n$\hat\pi$ = {:4.4f}\nerror = {:4.4f}%'
             .format(N,pi,error), alpha=0.1)
    plt.axis('square')
    plt.legend(frameon=True, framealpha=0.9, fontsize=10, loc="upper right")

# %%
np.random.seed(27)

plt.figure(figsize=(8,8))  # tamaño de la figura

plt.subplot(2,2,1)
mi_funcion_pi(N=100)
plt.subplot(2,2,2)
mi_funcion_pi(N=500)
plt.subplot(2,2,3)
mi_funcion_pi(N=1000)
plt.subplot(2,2,4)
mi_funcion_pi(N=1000000)

plt.show()

# %%
np.random.seed(42)

def mi_ecuacion_aprox(N=10000): 

    x_max = 1
    x_min = -1
    x_range = x_max-x_min
    
    # puntos aleatorios
    x = np.random.uniform(x_min, x_max, size=(1, N))
    y = np.random.uniform(0, 1, size=(1, N))

    # exito
    interior = (x**4) >= y
    exterior = np.invert(interior)

    # pintar
    plt.plot(x[interior], y[interior], 'b.')
    plt.plot(x[exterior], y[exterior], 'r.')

    #calcular
    integral = interior.sum()*x_range / N
    error = abs((integral - 1/3.0) / integral) * 100

    plt.plot(0, 0, label='N={:d}\n$\int_0^1 x^2 dx $ = {:4.4f}\nerror = {:4.4f}%'
             .format(N,integral,error), alpha=0.1)
    #plt.axis('square')
    plt.legend(frameon=True, framealpha=0.9, fontsize=10, loc="upper right")

# %%
plt.figure(figsize=(8,8))  # tamaño de la figura

plt.subplot(2,2,1)
mi_ecuacion_aprox(N=100)
plt.subplot(2,2,2)
mi_ecuacion_aprox(N=500)
plt.subplot(2,2,3)
mi_ecuacion_aprox(N=1000)
plt.subplot(2,2,4)
mi_ecuacion_aprox(N=10000)

plt.show()

# %% [markdown]
# $\int_0^1 x^2 dx $

# %%
#import libraries



#Funtion to roll the dice.

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries

d = {}

for i in range(60):
     if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  
  
        
#Initialize important variables





for i in range(n_simulations):
    
    #make a list of the colors that we choose
   
    

        
    #Convert it to a numpy array
   

    #find the number of each taht we picked
    
    
    
    
    #Keep track if the combination met the criteria
    
    
    
    
#print 'the probability of 3 white and 2 red is' in percentage

#print 'the probability of all the same color is' in percentage
# Out:
#   File <tokenize>:8
#     elif i > 9 and i < 30:
#     ^
# IndentationError: unindent does not match any outer indentation level
